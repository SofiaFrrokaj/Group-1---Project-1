# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
crime_data = pd.read_csv(Path('crime_data.csv'))
# Out:
# C:\Users\Nan\AppData\Local\Temp\ipykernel_18660\290000478.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_data = pd.read_csv(Path('crime_data.csv'))

# %%
crime_data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO  ...        44.0            INSIDE
# ...

# %%
crime_data.keys()
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'],
#       dtype='object')

# %%
crime_data=crime_data.dropna()

# %%
crime_data.tail()
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 704541   260543857    7/17/2014     18:30:00    7/17/2014     18:30:00
# 709635   487186695    7/13/2014     20:30:00    7/13/2014     20:45:00
# 713615   330740886    7/11/2014      1:10:00    7/11/2014      1:21:00
# 715850   919428487     7/9/2014     21:15:00     7/9/2014     21:26:00
# 717414   213481643     7/8/2014     20:50:00     7/8/2014     21:10:00
#
#            RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 704541  7/17/2014    359  OFFENSES AGAINST PUBLIC ADMINI  750.0
# 709635  7/14/2014    109                   GRAND LARCENY  439.0
# 713615  7/11/2014    118               DANGEROUS WEAPONS  793.0
# 715850   7/9/2014    352               CRIMINAL TRESPASS  203.0
# 717414   7/8/2014    236               DANGEROUS WEAPONS  782.0
#
#                                           PD_DESC  ... ADDR_PCT_CD  \
# 704541                           RESISTING ARREST  ...        79.0
# ...

# %%
crime_data=crime_data.rename(columns={'CMPLNT_NUM':"Complaint ID",
                                       'CMPLNT_FR_DT': "Crime Date",
                                       'CMPLNT_FR_TM':"Complaint Time",
                                         'CMPLNT_TO_DT':"Ending Date",
                                        'CMPLNT_TO_TM':"Ending Time", 
                                        'RPT_DT':"Reported Date",
                                        'KY_CD':"Offense Code",
                                        'OFNS_DESC':"Offense Description",
                                        'PD_CD':"Classification Code",
                                        'PD_DESC':"Classification Description",
                                        'CRM_ATPT_CPTD_CD':"Crime Status",
                                        'LAW_CAT_CD':"Offense Level", 
                                        'JURIS_DESC':"Jurisdiction",
                                        'BORO_NM':"Borough",
                                        'ADDR_PCT_CD':"Precinct",
                                        'LOC_OF_OCCUR_DESC':"Location Description", 
                                        'PREM_TYP_DESC':"Premise Description",
                                        'PARKS_NM':"Park Name",
                                        'HADEVELOPT':"Name of NYCHA Housing", 
                                        'X_COORD_CD':"X Coordinate", 
                                        'Y_COORD_CD':"Y Coordinate",
                                        'Latitude':"Latitude",
                                         'Longitude':"Longitude",
                                        })

# %%
crime_data.head()
# Out:
#        Complaint ID  Crime Date Complaint Time Ending Date Ending Time  \
# 12104     479888864  12/21/2015        9:31:00  12/21/2015     9:47:00
# 15600     817223136  12/18/2015       15:30:00  12/18/2015    15:35:00
# 16575     144702604  12/17/2015       22:30:00  12/17/2015    22:56:00
# 28742     426614014   12/8/2015       20:50:00   12/8/2015    20:58:00
# 43263     598084040  11/27/2015       11:25:00  11/27/2015    11:30:00
#
#       Reported Date  Offense Code      Offense Description  \
# 12104    12/21/2015           106           FELONY ASSAULT
# 15600    12/18/2015           105                  ROBBERY
# 16575    12/17/2015           126  MISCELLANEOUS PENAL LAW
# 28742     12/8/2015           236        DANGEROUS WEAPONS
# 43263    11/27/2015           235          DANGEROUS DRUGS
#
#        Classification Code          Classification Description  ... Precinct  \
# 12104                106.0           ASSAULT 2,1,PEACE OFFICER  ...     76.0
# ...

# %%
crime_data.columns
# Out:
# Index(['Complaint ID', 'Crime Date', 'Complaint Time', 'Ending Date',
#        'Ending Time', 'Reported Date', 'Offense Code', 'Offense Description',
#        'Classification Code', 'Classification Description', 'Crime Status',
#        'Offense Level', 'Jurisdiction', 'Borough', 'Precinct',
#        'Location Description', 'Premise Description', 'Park Name',
#        'Name of NYCHA Housing', 'X Coordinate', 'Y Coordinate', 'Latitude',
#        'Longitude', 'Lat_Lon'],
#       dtype='object')

# %%
#What percentage of crimes result in arrests?

df_crime_data=crime_data.dropna()

# Count total crimes
total_crimes = len(df_crime_data)

# Count crimes that resulted in arrests (assuming "Arrest" is the relevant status)
arrested_crimes = df_crime_data[df_crime_data["Crime Status"] == "COMPLETED"]

# Calculate percentage
arrest_rate = (len(arrested_crimes) / total_crimes) * 100

print(f"Percentage of crimes resulting in arrests: {arrest_rate:.2f}%")
# Out:
# Percentage of crimes resulting in arrests: 96.52%

# %%
#Which offenses are the most common?
common_offenses = df_crime_data["Offense Description"].value_counts().head(10)
display (common_offenses)

common_offenses.plot(kind="bar", title="Top 10 Most Common Offenses")


#how to make the plot more readable
common_offenses.plot(kind="bar", title="Top 10 Most Common Offenses")
plt.xticks
plt.ylabel("Number of Crimes")
plt.xlabel("Offense Description")
plt.show()
# Out:
# Offense Description
# DANGEROUS DRUGS                   33
# DANGEROUS WEAPONS                 10
# OFFENSES AGAINST PUBLIC ADMINI    10
# ASSAULT 3 & RELATED OFFENSES       9
# MISCELLANEOUS PENAL LAW            7
# HARRASSMENT 2                      7
# FRAUDS                             6
# PETIT LARCENY                      6
# ROBBERY                            5
# FELONY ASSAULT                     5
# Name: count, dtype: int64

# %%
#Which offenses are the least common?
rare_offenses = df_crime_data["Offense Description"].value_counts().tail(10)
display (rare_offenses)

rare_offenses.plot(kind="bar", title="Top 10 Least Common Offenses")
plt.xticks
plt.ylabel("Number of Crimes")
plt.xlabel("Offense Description")
plt.show()
# Out:
# Offense Description
# ROBBERY                          5
# FELONY ASSAULT                   5
# GRAND LARCENY                    5
# CRIMINAL TRESPASS                4
# POSSESSION OF STOLEN PROPERTY    3
# OFF. AGNST PUB ORD SENSBLTY &    1
# ADMINISTRATIVE CODE              1
# OTHER STATE LAWS                 1
# FORGERY                          1
# OFFENSES INVOLVING FRAUD         1
# Name: count, dtype: int64

# %%
#What we can learn from the above analysis is that:
#The most common offenses are related to drugs and weapons, while the least common offenses are related to forgery and offenses involving fraudulent activities. 
# This information could be useful for law enforcement agencies to allocate resources more effectively.

# %%
#Which locations are the most common for crimes to occur?
common_locations = df_crime_data["Premise Description"].value_counts().head()
display (common_locations)

common_locations.plot(kind="bar", title="Top Locations for Crimes")
# Out:
# Premise Description
# RESIDENCE - PUBLIC HOUSING    100
# PARK/PLAYGROUND                13
# STREET                          2
# Name: count, dtype: int64
# <Axes: title={'center': 'Top Locations for Crimes'}, xlabel='Premise Description'>

# %%
#How does the clearance rate (solved cases) vary by crime type?
df_clearance_rate = df_crime_data.groupby("Offense Description")["Crime Status"].value_counts(normalize=True).loc[:, "COMPLETED"].sort_values(ascending=False)
display(df_clearance_rate)
df_clearance_rate.plot(kind="barh", title="Clearance Rate by Crime Type")
plt.xlabel("Clearance Rate")
plt.ylabel("Offense Description")
plt.show()
# Out:
# Offense Description
# ADMINISTRATIVE CODE               1.000000
# GRAND LARCENY                     1.000000
# POSSESSION OF STOLEN PROPERTY     1.000000
# PETIT LARCENY                     1.000000
# OTHER STATE LAWS                  1.000000
# OFFENSES INVOLVING FRAUD          1.000000
# OFF. AGNST PUB ORD SENSBLTY &     1.000000
# MISCELLANEOUS PENAL LAW           1.000000
# HARRASSMENT 2                     1.000000
# FRAUDS                            1.000000
# FORGERY                           1.000000
# DANGEROUS WEAPONS                 1.000000
# DANGEROUS DRUGS                   1.000000
# CRIMINAL TRESPASS                 1.000000
# ROBBERY                           1.000000
# OFFENSES AGAINST PUBLIC ADMINI    0.900000
# FELONY ASSAULT                    0.800000
# ASSAULT 3 & RELATED OFFENSES      0.777778
# Name: proportion, dtype: float64

# %%
#How does the clearance rate vary by borough?
df_clearance_rate = df_crime_data.groupby("Borough")["Crime Status"].value_counts(normalize=True).loc[:, "COMPLETED"].sort_values(ascending=False)
display(df_clearance_rate)
df_clearance_rate.plot(kind="bar", title="Clearance Rate by Borough")
plt.xlabel("Borough")
plt.ylabel("Clearance Rate")
plt.show()
# Out:
# Borough
# MANHATTAN        1.000000
# QUEENS           1.000000
# BRONX            0.964286
# BROOKLYN         0.960000
# STATEN ISLAND    0.666667
# Name: proportion, dtype: float64

# %%
#How does the clearance rate vary by offense level?
df_clearance_rate = df_crime_data.groupby("Offense Level")["Crime Status"].value_counts(normalize=True).loc[:, "COMPLETED"].sort_values(ascending=False)
display(df_clearance_rate)
df_clearance_rate.plot(kind="bar", title="Clearance Rate by Offense Level")
plt.xlabel("Offense Level")
plt.ylabel("Clearance Rate")
plt.show()
# Out:
# Offense Level
# VIOLATION      1.000000
# FELONY         0.967742
# MISDEMEANOR    0.960000
# Name: proportion, dtype: float64

# %%
#How does the clearance rate vary by premise description?
df_clearance_rate = df_crime_data.groupby("Premise Description")["Crime Status"].value_counts(normalize=True).loc[:, "COMPLETED"].sort_values(ascending=False)
display(df_clearance_rate)
df_clearance_rate.plot(kind="bar", title="Clearance Rate by Premise Description")
plt.xlabel("Premise Description")
plt.ylabel("Clearance Rate")
plt.show()
# Out:
# Premise Description
# PARK/PLAYGROUND               1.00
# RESIDENCE - PUBLIC HOUSING    0.97
# STREET                        0.50
# Name: proportion, dtype: float64

# %%
#How does the clearance rate vary by jurisdiction?
df_clearance_rate = df_crime_data.groupby("Jurisdiction")["Crime Status"].value_counts(normalize=True).loc[:, "COMPLETED"].sort_values(ascending=False)
display(df_clearance_rate)
df_clearance_rate.plot(kind="bar", title="Clearance Rate by Jurisdiction")
plt.xlabel("Jurisdiction")
plt.ylabel("Clearance Rate")
plt.show()
# Out:
# Jurisdiction
# N.Y. HOUSING POLICE    0.970588
# N.Y. POLICE DEPT       0.923077
# Name: proportion, dtype: float64

# %%
Based on the above data analysis, we can derive several insights:

1. **Arrest Rate**:
    - The percentage of crimes resulting in arrests is very high at approximately 96.52%. This indicates that the majority of reported crimes lead to arrests.

2. **Common Offenses**:
    - The most common offenses include dangerous drugs, dangerous weapons, and offenses against public administration. 
    - This suggests that drug-related and weapon-related crimes are prevalent in the dataset.

3. **Rare Offenses**:
    - The least common offenses include forgery and offenses involving fraud. These types of crimes are less frequently reported or occur less often in the dataset.

4. **Common Locations for Crimes**:
    - The most common locations for crimes to occur are public housing residences and parks/playgrounds. This information could be useful for law enforcement agencies to focus their resources on these areas to prevent crimes.

5. **Clearance Rate by Various Factors**:
    - The clearance rate (solved cases) varies by crime type, borough, offense level, premise description, and jurisdiction. 
    - For example, crimes that occur in private residences have a higher clearance rate compared to those that occur on the street. 
    - Similarly, certain offense types, such as petit larceny, have a higher clearance rate compared to felony assault. Additionally, the clearance rate can also vary based on the jurisdiction and offense level.

6. **Insights for Law Enforcement**:
    - The analysis provides valuable insights into the factors that can impact the clearance rate of a crime. Law enforcement agencies can use this information to prioritize their resources and improve their investigative efforts. For example, focusing on high-crime areas such as public housing, and addressing prevalent offenses like drug and weapon-related crimes.

Overall, the analysis highlights the importance of understanding crime patterns and clearance rates to enhance law enforcement strategies and resource allocation.
