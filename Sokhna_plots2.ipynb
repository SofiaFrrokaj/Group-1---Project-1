# %%
import pandas as pd
from pathlib import Path

# %%
crime_data = pd.read_csv('crime_data.csv', encoding='ISO-8859-1')
# Out:
# C:\Users\sokhna.thiaw\AppData\Local\Temp\ipykernel_4760\3480612292.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_data = pd.read_csv('crime_data.csv', encoding='ISO-8859-1')

# %%
# Display the first few rows of the dataset
crime_data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO  ...        44.0            INSIDE
# ...

# %%
# display the columns of the dataset
crime_data.keys()
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'],
#       dtype='object')

# %%
# drop the columns that are empty
crime_data =crime_data.dropna()

# %%
# Display the first few rows of the dataset
crime_data.head()
# Out:
#        CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 12104   479888864   12/21/2015      9:31:00   12/21/2015      9:47:00
# 15600   817223136   12/18/2015     15:30:00   12/18/2015     15:35:00
# 16575   144702604   12/17/2015     22:30:00   12/17/2015     22:56:00
# 28742   426614014    12/8/2015     20:50:00    12/8/2015     20:58:00
# 43263   598084040   11/27/2015     11:25:00   11/27/2015     11:30:00
#
#            RPT_DT  KY_CD                OFNS_DESC  PD_CD  \
# 12104  12/21/2015    106           FELONY ASSAULT  106.0
# 15600  12/18/2015    105                  ROBBERY  386.0
# 16575  12/17/2015    126  MISCELLANEOUS PENAL LAW  760.0
# 28742   12/8/2015    236        DANGEROUS WEAPONS  782.0
# 43263  11/27/2015    235          DANGEROUS DRUGS  567.0
#
#                                   PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 12104           ASSAULT 2,1,PEACE OFFICER  ...        76.0           REAR OF
# ...

# %%
# Rename the columns to make them more readable
crime_data=crime_data.rename(columns={'CMPLNT_NUM':"Complaint ID",
                                       'CMPLNT_FR_DT': "Crime Date",
                                       'CMPLNT_FR_TM':"Complaint Time",
                                         'CMPLNT_TO_DT':"Ending Date",
                                        'CMPLNT_TO_TM':"Ending Time", 
                                        'RPT_DT':"Reported Date",
                                        'KY_CD':"Offense Code",
                                        'OFNS_DESC':"Offense Description",
                                        'PD_CD':"Classification Code",
                                        'PD_DESC':"Classification Description",
                                        'CRM_ATPT_CPTD_CD':"Crime Status",
                                        'LAW_CAT_CD':"Offense Level", 
                                        'JURIS_DESC':"Jurisdiction",
                                        'BORO_NM':"Borough",
                                        'ADDR_PCT_CD':"Precinct",
                                        'LOC_OF_OCCUR_DESC':"Location Description", 
                                        'PREM_TYP_DESC':"Premise Description",
                                        'PARKS_NM':"Park Name",
                                        'HADEVELOPT':"Name of NYCHA Housing", 
                                        'X_COORD_CD':"X Coordinate", 
                                        'Y_COORD_CD':"Y Coordinate",
                                        'Latitude':"Latitude",
                                         'Longitude':"Longitude",
                                        })

crime_data.head()
# Out:
#        Complaint ID  Crime Date Complaint Time Ending Date Ending Time  \
# 12104     479888864  12/21/2015        9:31:00  12/21/2015     9:47:00
# 15600     817223136  12/18/2015       15:30:00  12/18/2015    15:35:00
# 16575     144702604  12/17/2015       22:30:00  12/17/2015    22:56:00
# 28742     426614014   12/8/2015       20:50:00   12/8/2015    20:58:00
# 43263     598084040  11/27/2015       11:25:00  11/27/2015    11:30:00
#
#       Reported Date  Offense Code      Offense Description  \
# 12104    12/21/2015           106           FELONY ASSAULT
# 15600    12/18/2015           105                  ROBBERY
# 16575    12/17/2015           126  MISCELLANEOUS PENAL LAW
# 28742     12/8/2015           236        DANGEROUS WEAPONS
# 43263    11/27/2015           235          DANGEROUS DRUGS
#
#        Classification Code          Classification Description  ... Precinct  \
# 12104                106.0           ASSAULT 2,1,PEACE OFFICER  ...     76.0
# ...

# %%
# change the data type of the columns to datetime
crime_data['Crime Date'] = pd.to_datetime(crime_data['Crime Date'], errors='coerce')

# %%
# Extract the year, month and day of the week from the Crime Date column
crime_data['Month'] = crime_data['Crime Date'].dt.month_name()
crime_data['Day of Week'] = crime_data['Crime Date'].dt.day_name()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#I'm going to count crimes by month
crime_by_month = crime_data['Month'].value_counts().sort_index()

# define correct order of months
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Convert the 'Month' column to categorical with a defined order
crime_by_month.index = pd.CategoricalIndex(crime_by_month.index, categories=months, ordered=True)
crime_by_month = crime_by_month.sort_index()
 # Change the size of the plot
 # change the color of the plot
 # rotate the x-axis labels
    # add labels and title
    # save the plot as a png file
    # display the plot
plt.figure(figsize=(12,6))
sns.barplot(x=crime_by_month.index, y=crime_by_month.values, color='#0f4662') 
plt.xticks(rotation=45)
plt.xlabel("Month", fontsize=12, color= '#7994a0', fontweight='bold')
plt.ylabel("Number of Crimes", fontsize=12, color= '#7994a0', fontweight='bold')
plt.title("Crimes by Month", fontsize=15, color= '#7994a0', fontweight='bold')
plt.tight_layout()
plt.savefig('Monthly.png')
plt.show()

# %%
#I'm going to count crimes by day of the week
crime_by_day = crime_data['Day of Week'].value_counts().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

 # Change the size of the plot
 # change the color of the plot
 # rotate the x-axis labels
    # add labels and title
    # save the plot as a png file
    # display the plot
plt.figure(figsize=(10, 5))
sns.barplot(x=crime_by_day.index, y=crime_by_day.values, color= '#0f4662')
plt.xticks(rotation=45)
plt.xlabel("Day of the Week", color='#7994a0', fontsize=12, fontweight='bold')
plt.ylabel("Number of Crimes", color='#7994a0', fontsize=12, fontweight='bold')
plt.title("Crimes by Day of the Week", color='#7994a0', fontsize=15, fontweight='bold')
plt.savefig('Weekly.png')
plt.show()

# %%
# Top areas with most crimes
crime_by_borough = crime_data['Borough'].value_counts().head(10)

 # Change the size of the plot
 # change the color of the plot
 # rotate the x-axis labels
    # add labels and title
    # save the plot as a png file
    # display the plot
plt.figure(figsize=(10, 5))
sns.barplot(x=crime_by_borough.index, y=crime_by_borough.values, color='#0f4662')
plt.xticks(rotation=45)
plt.xlabel("Boroughs", color='#7994a0', fontsize=12, fontweight='bold')
plt.ylabel("Number of Crimes", color='#7994a0', fontsize=12, fontweight='bold')
plt.title("Top Borough with the Most Crimes", color='#7994a0', fontsize=15, fontweight='bold')
plt.show()

# %%
# I'm going to create a pivot table for crime correlation
crime_corr = crime_data.pivot_table(index="Crime Date", columns= "Offense Description", aggfunc="size", fill_value=0.5)

# Plot correlation matrix
# Change the size of the plot
 # change the color of the plot
 # rotate the x-axis labels
    # add labels and title
    # save the plot as a png file
    # display the plot
plt.figure(figsize=(12, 6), dpi=85)
sns.heatmap(crime_corr.corr(), cmap="Blues", annot=False)
plt.title("Correlation Between Different Types of Crimes")
plt.savefig('Correlation.png')
plt.show()

# %%
#testing

# %%
#test commit 1

# %%
#test commit 2
